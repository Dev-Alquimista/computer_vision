# %%
import numpy as np 
import pandas as pd 
import torch 
import cv2 
import os 
import sys 

from google.colab import drive 
from google.colab.patches import cv2_imshow
from IPython.display import Image, clear_output

# %%
# !git clone https://github.com/ultralytics/yolov3
# !cd yolov3;pip install -qr requirements.txt
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10029, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10029 (delta 3), reused 9 (delta 3), pack-reused 10017
# Receiving objects: 100% (10029/10029), 9.36 MiB | 24.95 MiB/s, done.
# Resolving deltas: 100% (6762/6762), done.
#      |████████████████████████████████| 596 kB 5.1 MB/s
#      |████████████████████████████████| 1.8 MB 47.6 MB/s
#      |████████████████████████████████| 153 kB 65.5 MB/s
#      |████████████████████████████████| 181 kB 69.0 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...

# %%
# !mkdir /content/images
# !wget -O ./images/beatles01.jpg https://raw.githubusercontent.com/chulminkw/DLCV/master/data/image/beatles01.jpg
# !wget -O ./images/baseball01.jpg https://raw.githubusercontent.com/chulminkw/DLCV/master/data/image/baseball01.jpg
# !wget -O ./images/Jonh_Wick_small.mp4 https://github.com/chulminkw/DLCV/blob/master/data/video/John_Wick_small.mp4?raw=true
# !wget -O ./images/Night_Day_Chase.mp4 https://github.com/chulminkw/DLCV/blob/master/data/video/Night_Day_Chase.mp4?raw=true
# !wget -O ./images/seoul.jpg https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Gangnam_Seoul_January_2009.jpg/1280px-Gangnam_Seoul_January_2009.jpg
# !wget -O ./images/intersection.jpg https://news.mit.edu/sites/default/files/styles/news_article__image_gallery/public/images/202205/MIT_Eco-Driving-01_0.jpg?itok=tHw5dBk-
# Out:
# mkdir: cannot create directory ‘/content/images’: File exists
# --2022-07-22 02:54:03--  https://raw.githubusercontent.com/chulminkw/DLCV/master/data/image/beatles01.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 383118 (374K) [image/jpeg]
# Saving to: ‘./images/beatles01.jpg’
#
# ./images/beatles01. 100%[===================>] 374.14K  --.-KB/s    in 0.03s
#
# 2022-07-22 02:54:03 (10.7 MB/s) - ‘./images/beatles01.jpg’ saved [383118/383118]
#
# --2022-07-22 02:54:03--  https://raw.githubusercontent.com/chulminkw/DLCV/master/data/image/baseball01.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.12.0+cu113 (CPU)

# %%
# !cd yolov3/data/images; ls -lia
# !cd ./images; ls -lia
# Out:
# total 656
# 3539107 drwxr-xr-x 2 root root   4096 Jul 22 02:33 .
# 3539095 drwxr-xr-x 5 root root   4096 Jul 22 02:33 ..
# 3539108 -rw-r--r-- 1 root root 487438 Jul 22 02:33 bus.jpg
# 3539109 -rw-r--r-- 1 root root 168949 Jul 22 02:33 zidane.jpg
# total 3312
# 3539034 drwxr-xr-x 2 root root    4096 Jul 22 02:46 .
# 3538962 drwxr-xr-x 1 root root    4096 Jul 22 02:46 ..
# 3539169 -rw-r--r-- 1 root root   76279 Jul 22 02:46 baseball01.jpg
# 3539158 -rw-r--r-- 1 root root  383118 Jul 22 02:46 beatles01.jpg
# 3539184 -rw-r--r-- 1 root root  781269 May 16 19:37 intersection.jpg
# 3539170 -rw-r--r-- 1 root root 1794863 Jul 22 02:46 Jonh_Wick_small.mp4
# 3539183 -rw-r--r-- 1 root root  336122 Jun  7 04:51 seoul.jpg

# %%
# !cd yolov3;python detect.py --weights yolov3.pt --img 640 --conf 0.5 --source ./images
# Out:
# ...
# detect: weights=['yolov3.pt'], source=./images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-21-g92c3bd7 torch 1.12.0+cu113 CPU
#
# ...
# 100% 119M/119M [00:02<00:00, 47.8MB/s]
#
# Fusing layers...
# Model Summary: 261 layers, 61922845 parameters, 0 gradients
# Traceback (most recent call last):
#   File "detect.py", line 244, in <module>
#     main(opt)
#   File "detect.py", line 239, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 95, in run
# ...

# %%
# !cd yolov3;python detect.py --weights yolov3.pt --img 640 --conf 0.25 --source  /content/images/Night_Day_Chase.mp4 \
                            --project=/content/data/run_video --exist-ok --line-thickness 1
# Out:
# detect: weights=['yolov3.pt'], source=/content/images/Night_Day_Chase.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/data/run_video, name=exp, exist_ok=True, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-21-g92c3bd7 torch 1.12.0+cu113 CPU
#
# Fusing layers...
# Model Summary: 261 layers, 61922845 parameters, 0 gradients
# video 1/1 (1/1383) /content/images/Night_Day_Chase.mp4: 288x640 1 person, 1 motorcycle, Done. (1.371s)
# video 1/1 (2/1383) /content/images/Night_Day_Chase.mp4: 288x640 1 person, 1 motorcycle, Done. (1.298s)
# video 1/1 (3/1383) /content/images/Night_Day_Chase.mp4: 288x640 1 person, 1 motorcycle, Done. (1.302s)
# ...
