# %% [markdown]
# #### Object detection network
# 1. Object detection network 개요
#     * Feature Extractor Network
#         - VGG , RESNET, INCEPTION
#     * Object Detection Netowk
#         - Pascal VOC/MS-COCO
#     * Region Proposal
# 2. Image Resolution, FPS, Detection
#     * Image Resolution이 높으면 Detection 성능도 높아진다.
#     * Image Resolution이 높으면 FPS는 떨어진다.
